# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Grades/Grades.csv')
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.tail()
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# ...

# %%
df.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# ...

# %%
 df=df.drop(columns=['Seat No.'])

# %%
df.head(5)
# Out:
#   PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0     B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1      A      D     D+         D     B-      C      D      A     D+      D
# 2      A      B      A        B-     B+      A     B-     B+     A-     A-
# 3      D     C+     D+         D      D     A-     D+     C-      D     C+
# 4     A-     A-     A-        B+      A      A     A-     B+      A     A-
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 42 columns]

# %%
df.describe()
# Out:
#              CGPA
# count  571.000000
# mean     2.954888
# std      0.620552
# min      0.800000
# 25%      2.538000
# 50%      3.029000
# 75%      3.451000
# max      3.985000

# %%
mapping={'A':0,'B':1,'C':2,'D':3,'A-':10,'B_':9,'C-':8,'D-':7}

# %%
c_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="objext":
        c_col.append(i)
print("Categorical data:",c_col)

n_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        n_col.append(i)
print("Numerical data:",n_col)
print("\n")
# Out:
# Categorical data: []
# Numerical data: ['CGPA']

# %%
df
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
# ...

# %%
plt.figure(figsize=(20,15),facecolor='red')
plotnumber=1

for col in n_col:
    if plotnumber<=8:
        ax=plt.subplot(2,4,plotnumber)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize=20)
        
    plotnumber+=1
plt.tight_layout()

# %%
df.describe()
# Out:
#              CGPA
# count  571.000000
# mean     2.954888
# std      0.620552
# min      0.800000
# 25%      2.538000
# 50%      3.029000
# 75%      3.451000
# max      3.985000

# %%
y=df['CGPA']

# %%
y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# 570    1.753
# Name: CGPA, Length: 571, dtype: float64

# %%
x1=df.drop(columns=['CGPA'])

# %%
x1
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %% [raw]
# le=LabelEncoder()

# %%
df.describe()
# Out:
#              CGPA
# count  571.000000
# mean     2.954888
# std      0.620552
# min      0.800000
# 25%      2.538000
# 50%      3.029000
# 75%      3.451000
# max      3.985000

# %%
#data skewed to left

# %%
df.isnull().any()
# Out:
# PH-121       False
# HS-101       False
# CY-105        True
# HS-105/12     True
# MT-111        True
# CS-105       False
# CS-106        True
# EL-102        True
# EE-119        True
# ME-107        True
# CS-107        True
# HS-205/20     True
# MT-222        True
# EE-222        True
# MT-224        True
# CS-210        True
# CS-211        True
# CS-203        True
# CS-214        True
# EE-217        True
# CS-212        True
# CS-215        True
# MT-331        True
# EF-303        True
# HS-304        True
# CS-301        True
# CS-302        True
# TC-383        True
# MT-442        True
# EL-332        True
# CS-318        True
# CS-306        True
# CS-312        True
# CS-317        True
# CS-403        True
# CS-421        True
# CS-406        True
# CS-414        True
# CS-419        True
# CS-423        True
# CS-412        True
# CGPA         False
# dtype: bool

# %%
df.shape
# Out:
# (571, 42)

# %%
df.isnull().sum()
# Out:
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 42 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     571 non-null    object
#  1   HS-101     571 non-null    object
#  2   CY-105     570 non-null    object
#  3   HS-105/12  570 non-null    object
#  4   MT-111     569 non-null    object
#  5   CS-105     571 non-null    object
#  6   CS-106     569 non-null    object
#  7   EL-102     569 non-null    object
#  8   EE-119     569 non-null    object
#  9   ME-107     569 non-null    object
#  10  CS-107     569 non-null    object
#  11  HS-205/20  566 non-null    object
#  12  MT-222     566 non-null    object
#  13  EE-222     564 non-null    object
#  14  MT-224     564 non-null    object
#  15  CS-210     564 non-null    object
#  16  CS-211     566 non-null    object
#  17  CS-203     566 non-null    object
#  18  CS-214     565 non-null    object
# ...

# %%
df.head(50)
# Out:
#    PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0      B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1       A      D     D+         D     B-      C      D      A     D+      D
# 2       A      B      A        B-     B+      A     B-     B+     A-     A-
# 3       D     C+     D+         D      D     A-     D+     C-      D     C+
# 4      A-     A-     A-        B+      A      A     A-     B+      A     A-
# 5       A     B-      B        D+     C+     A-     C+      B     B+     B+
# 6      B-     C-     A-         D     A-      B      A     B+     A-     B+
# 7      B+     B+     C+         C      C     A-     C-     A-      B     A-
# 8      A-      C     A-        D+      B     A-     A-     A-     B+     A-
# 9       A      B     C+         B      B     A-      C     B-     A-      A
# 10     A-     B-     B+        C-     C-     B-     C+     B-      A     A-
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#NULL VALUES ARE PRESENT

# %%
#Divind dataset into features and labels

# %%
y=df['CGPA']

# %%
x=df.drop(columns=['CGPA'])

# %%
x
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
# ...

# %%
y.isnull().any()
# Out:
# False

# %%
x.isnull().any()
# Out:
# PH-121       False
# HS-101       False
# CY-105        True
# HS-105/12     True
# MT-111        True
# CS-105       False
# CS-106        True
# EL-102        True
# EE-119        True
# ME-107        True
# CS-107        True
# HS-205/20     True
# MT-222        True
# EE-222        True
# MT-224        True
# CS-210        True
# CS-211        True
# CS-203        True
# CS-214        True
# EE-217        True
# CS-212        True
# CS-215        True
# MT-331        True
# EF-303        True
# HS-304        True
# CS-301        True
# CS-302        True
# TC-383        True
# MT-442        True
# EL-332        True
# CS-318        True
# CS-306        True
# CS-312        True
# CS-317        True
# CS-403        True
# CS-421        True
# CS-406        True
# CS-414        True
# CS-419        True
# CS-423        True
# CS-412        True
# dtype: bool

# %%
x.columns.tolist()
# Out:
# ['PH-121',
#  'HS-101',
#  'CY-105',
#  'HS-105/12',
#  'MT-111',
#  'CS-105',
#  'CS-106',
#  'EL-102',
#  'EE-119',
#  'ME-107',
#  'CS-107',
#  'HS-205/20',
#  'MT-222',
#  'EE-222',
#  'MT-224',
#  'CS-210',
#  'CS-211',
#  'CS-203',
#  'CS-214',
#  'EE-217',
#  'CS-212',
#  'CS-215',
#  'MT-331',
#  'EF-303',
#  'HS-304',
#  'CS-301',
#  'CS-302',
#  'TC-383',
#  'MT-442',
#  'EL-332',
#  'CS-318',
#  'CS-306',
#  'CS-312',
#  'CS-317',
#  'CS-403',
#  'CS-421',
#  'CS-406',
#  'CS-414',
#  'CS-419',
#  'CS-423',
#  'CS-412']

# %%
df.columns
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222',
#        'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
#        'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
#        'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
#        'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412', 'CGPA'],
#       dtype='object')

# %%
x.columns
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222',
#        'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
#        'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
#        'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
#        'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 42 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     571 non-null    object
#  1   HS-101     571 non-null    object
#  2   CY-105     570 non-null    object
#  3   HS-105/12  570 non-null    object
#  4   MT-111     569 non-null    object
#  5   CS-105     571 non-null    object
#  6   CS-106     569 non-null    object
#  7   EL-102     569 non-null    object
#  8   EE-119     569 non-null    object
#  9   ME-107     569 non-null    object
#  10  CS-107     569 non-null    object
#  11  HS-205/20  566 non-null    object
#  12  MT-222     566 non-null    object
#  13  EE-222     564 non-null    object
#  14  MT-224     564 non-null    object
#  15  CS-210     564 non-null    object
#  16  CS-211     566 non-null    object
#  17  CS-203     566 non-null    object
#  18  CS-214     565 non-null    object
# ...

# %%
x
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
# ...

# %%
for columns in x:
  x[columns].fillna(value=x[columns].mode()[0],inplace=True)

# %%
x
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
# ...

# %%
x.isnull().any()
# Out:
# PH-121       False
# HS-101       False
# CY-105       False
# HS-105/12    False
# MT-111       False
# CS-105       False
# CS-106       False
# EL-102       False
# EE-119       False
# ME-107       False
# CS-107       False
# HS-205/20    False
# MT-222       False
# EE-222       False
# MT-224       False
# CS-210       False
# CS-211       False
# CS-203       False
# CS-214       False
# EE-217       False
# CS-212       False
# CS-215       False
# MT-331       False
# EF-303       False
# HS-304       False
# CS-301       False
# CS-302       False
# TC-383       False
# MT-442       False
# EL-332       False
# CS-318       False
# CS-306       False
# CS-312       False
# CS-317       False
# CS-403       False
# CS-421       False
# CS-406       False
# CS-414       False
# CS-419       False
# CS-423       False
# CS-412       False
# dtype: bool

# %%
#Nan values removed

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 41 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     571 non-null    object
#  1   HS-101     571 non-null    object
#  2   CY-105     571 non-null    object
#  3   HS-105/12  571 non-null    object
#  4   MT-111     571 non-null    object
#  5   CS-105     571 non-null    object
#  6   CS-106     571 non-null    object
#  7   EL-102     571 non-null    object
#  8   EE-119     571 non-null    object
#  9   ME-107     571 non-null    object
#  10  CS-107     571 non-null    object
#  11  HS-205/20  571 non-null    object
#  12  MT-222     571 non-null    object
#  13  EE-222     571 non-null    object
#  14  MT-224     571 non-null    object
#  15  CS-210     571 non-null    object
#  16  CS-211     571 non-null    object
#  17  CS-203     571 non-null    object
#  18  CS-214     571 non-null    object
# ...

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 571 entries, 0 to 570
# Series name: CGPA
# Non-Null Count  Dtype
# --------------  -----
# 571 non-null    float64
# dtypes: float64(1)
# memory usage: 4.6 KB

# %%
sns.heatmap(x.isnull())
# Out:
# <Axes: >

# %%
#Checking Data Distribution


plt.figure(figsize=(20,15),facecolor='red')
plotnumber=1

for col in n_col:
    if plotnumber<=8:
        ax=plt.subplot(2,4,plotnumber)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize=20)
        
    plotnumber+=1
plt.tight_layout()

# %%
x.describe()
# Out:
#        PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# count     571    571    571       571    571    571    571    571    571
# unique     13     12     13        13     13     11     13     13     12
# top        A-     A-      A         A     A-      A     A-     A-     A-
# freq      112     82    178        97    107    151    118    107    139
#
#        ME-107  ... CS-306 CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419  \
# count     571  ...    571    571    571    571    571    571    571    571
# unique     13  ...     13     14     12     11     13     14     13     12
# top        A-  ...     A-     A+     B-      A      B     A-      A     A-
# freq       81  ...    129    103     91    145     98    262    189    133
#
#        CS-423 CS-412
# count     571    571
# unique     12     13
# top        A-     A-
# freq      136    236
#
# [4 rows x 41 columns]

# %%
#Checking Outliers


plt.figure(figsize=(20,15),facecolor='red')
plotnumber=1

for col in n_col:
    if plotnumber<=8:
        ax=plt.subplot(2,4,plotnumber)
        sns.boxplot(df[col])
        plt.xlabel(col,fontsize=20)
        plt.yticks(rotation=0,fontsize=10)
        
    plotnumber+=1
plt.tight_layout()

# %%
x.skew
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.skew of     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# ...

# %%
#Checking Realtionship


plt.figure(figsize=(20,15),facecolor='yellow')
plotnumber=1

for col in x:
    if plotnumber<=8:
        ax=plt.subplot(2,4,plotnumber)
        plt.scatter(x[col],y)
        plt.xlabel(col,fontsize=20)
        plt.ylabel('CGPA',fontsize=10)
        
    plotnumber+=1
plt.tight_layout()

# %%
#Model Building including all features
#Data Scaling: Formula:-   Z=(x-mean)/std

# %%
scaler= StandardScaler()

# %%
pd.unique(x["PH-121"])
# Out:
# array(['B-', 'A', 'D', 'A-', 'B+', 'B', 'C+', 'C', 'C-', 'D+', 'WU', 'A+',
#        'F'], dtype=object)

# %%
grades={'B-':6, 'A':2, 'D':11, 'A-':3, 'B+':4, 'B':5, 'C+':7, 'C':8, 'C-':9, 'D+':10, 'WU':12, 'A+':1,
       'F':13,}

# %% [raw]
# type(x)

# %%
for item in x:
    x[item]=x[item].replace(grades)

# %%
x.head()
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0       6      10       9          8       9      10      11       9       6
# 1       2      11      10         11       6       8      11       2      10
# 2       2       5       2          6       4       2       6       4       3
# 3      11       7      10         11      11       3      10       9      11
# 4       3       3       3          4       2       2       3       4       2
#
#    ME-107  ... CS-306  CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419  \
# 0       9  ...      8       9      9      9      9      3      2      9
# 1      11  ...     11      10     11      8     11      3      6      8
# 2       3  ...      3       5      5      2      8      2      2      2
# 3       7  ...      9      10      8     10      9      6      5      7
# 4       3  ...      3       6      4      4      6      3      2      3
#
#   CS-423  CS-412
# 0      5       3
# 1      8       5
# ...

# %%
df1=pd.concat([x,y],axis=1)

# %%
df1.hist(bins=30,figsize=(15,15))
plt.show()

# %%
df1.describe()
# Out:
#            PH-121      HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     4.970228    6.192644    4.183888    5.350263    5.021016    4.005254
# std      2.942875    2.728282    2.797772    3.103464    2.837638    2.500872
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      3.000000    4.000000    2.000000    3.000000    3.000000    2.000000
# 50%      4.000000    6.000000    3.000000    5.000000    4.000000    3.000000
# 75%      7.000000    8.000000    5.500000    8.000000    7.000000    5.000000
# max     13.000000   13.000000   13.000000   13.000000   13.000000   11.000000
#
#            CS-106      EL-102      EE-119      ME-107  ...      CS-302  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     5.154116    5.066550    4.975482    5.922942  ...    4.718039
# ...

# %%
#Mean is greater than median:right skewness can be seen

# %%
df.to_csv('SCP_DC')

# %%
#Predicting - CGPA of a student based on different grades in four years.

# %%
x=df1.drop(columns=['CGPA'])

# %%
#Model Building

# %%
M1=[]
M2=[]
M3=[]
M4=[]
for item in [x]:
    for i in item:
      if i[3]=='1':
        M1.append(i)
      elif i[3]=='2':
        M2.append(i)
      elif i[3]=='3':
        M3.append(i)
      elif i[3]=='4':
        M4.append(i)

# %%
y=df1['CGPA'].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=25)

# %%
from sklearn import linear_model

# %%
lm1 =linear_model.LinearRegression()
#new model build

# %%
x=x.drop(columns=["HS-304"])

# %%
grades={'I':0}

# %%
for item in x:
    x[item]=x[item].replace(grades)

# %%
x
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         6      10       9          8       9      10      11       9
# 1         2      11      10         11       6       8      11       2
# 2         2       5       2          6       4       2       6       4
# 3        11       7      10         11      11       3      10       9
# 4         3       3       3          4       2       2       3       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       5       2       2          3       1       2       3       3
# 567       1       2       2          2       2       2       2       3
# 568       5       2       3          4       2       2       2       2
# 569       2       4      11          2      11      10       6       9
# 570       8      11      11          8       8      10       5       7
#
#      EE-119  ME-107  ...  EF-303  CS-301 CS-302 TC-383 MT-442 EL-332 CS-318  \
# ...
